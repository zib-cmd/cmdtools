# %%
# %autoreload 2
import sys
sys.path.append('src')
import sqra
import numpy as np
import ajc
import ajcs
from scipy.linalg import expm
import scipy.sparse.linalg as spl
import matplotlib.pyplot as plt

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

# %%
class PaperPlots:
    def __init__(self, model):
        self.model = model
        self.Qs = model.Qs
        self.dt = np.array(model.dts)

        self.ajc = ajc.AJCGalerkin(np.dstack(self.Qs), self.dt)
        self.nt = np.size(self.Qs, 0)
        self.nx = np.size(self.Qs[0], 0)
    
    ######

    def jumpactivity(self, p0):
        return self.ajc.geiger(p0)

    def sync(self, p0):
        pp = self.jumpactivity(p0)
        return self.ajc.synchronize(pp)

    def kernelmatrix(self):
        return self.ajc.km

    def koopman_sync(self):
            k = np.zeros((self.nx, self.nx))
            for i in range(self.nx):
                x0 = np.zeros((self.nx, self.nt))
                x0[i,0] = 1
                k[i, :] = self.sync(x0)[:,-1]
            return k

    def koopman_q(self):
        k = np.identity(self.nx)
        for (i,t) in enumerate(self.dt):
            k = k @ expm(t * self.Qs[i])
        return k

    def koopman_error(self):
        ks = self.koopman_sync()
        kq = self.koopman_q()
        return np.linalg.norm(ks-kq, 2)

    #######

    def plot_transkernel(self):
        p = plt.imshow(self.kernelmatrix())

        cb = plt.colorbar()
        #cb.set_label("transition probability")
        plt.xticks()
        plt.yticks()
        plt.xlabel("X x T")
        plt.ylabel("X x T")
        return p

    def plot_jumpactivity(self, x0=0):
        p0 = np.zeros((self.nx,self.nt))
        p0[x0,0] = 1

        p = plt.imshow(self.jumpactivity(p0))

        #cb = plt.colorbar()
        #cb.set_label("jump activity")

        plt.ylabel("X")
        plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        return p

    def plot_sync(self, x0=0, p0=None):
        if p0 is None:
            p0 = np.zeros((self.nx,self.nt))
            p0[x0,0] = 1
        ps = self.sync(p0)

        p = plt.imshow(ps)

        #cb = plt.colorbar()
        #cb.set_label("probability (synchronized, one state)")

        plt.ylabel("X")
        plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        #plt.clim((0,1))
        return p

    def plot_koopman_sync(self):
        plt.imshow(self.koopman_sync())

        plt.xlabel("X")
        plt.ylabel("X")
        plt.xticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))

        cb = plt.colorbar()
        t2 = sum(self.dt)
        t1 = t2 - self.dt[-1]
        cb.set_label(f"probability (synchronized, t $\in  [{t1},{t2}]  $)")
        plt.clim((0,1))

    def plot_koopman_q(self):
        plt.imshow(self.koopman_q())
        plt.xlabel("X")
        plt.ylabel("X")

        plt.xticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))

        cb = plt.colorbar()
        t2 = sum(self.dt)
        cb.set_label(f"probability (exact, t={t2})")
        plt.clim((0,1))

    def plot_all(self, save=False):
        self.plot_transkernel()
        if save:
            plt.savefig(self.model.name() + "_transkernel.pdf")
        plt.show()

        self.plot_jumpactivity(0)
        if save:
            plt.savefig(self.model.name() + "_jumpactivity.pdf")
        plt.show()

        self.plot_sync(0)
        if save:
            plt.savefig(self.model.name() + "_sync.pdf")
        plt.show()

        self.plot_koopman_sync()
        if save:
            plt.savefig(self.model.name() + "_koopman_sync.pdf")
        plt.show()

        self.plot_koopman_q()
        if save:
            plt.savefig(self.model.name() + "_koopman_q.pdf")
        plt.show()

# %%
import scipy.sparse as sps

class PaperPlotsSparse(PaperPlots):
    def __init__(self, model):
        self.model = model
        self.Qs = model.Qs
        self.dt = np.array(model.dts)

        self.ajcs = ajcs.AJCS(self.Qs, self.dt)
        self.nt = np.size(self.Qs, 0)
        self.nx = np.size(self.Qs[0], 0)

    def jumpactivity(self, p0):
        return self.ajcs.geiger(p0.T).T

    def sync(self, p0):
        pp = self.jumpactivity(p0)
        return self.ajcs.synchronize(pp)

    def kernelmatrix(self):
        return  self.ajcs.km.toarray()

    def koopman_q(self):
        k = sps.identity(self.nx)
        for (i,t) in enumerate(self.dt):
            k = k @ spl.expm(t * self.Qs[i])
        return k

    def koopman_error(self):
        #ks = self.ajcs.koopman_system()
        ks = self.koopman_sync()
        kq = self.koopman_q()
        return np.linalg.norm(ks-kq, 2)

# %%
from copy import deepcopy

class ApproximationError:
    def __init__(self, model, nt = 10, tmax = 50):
        self.nts = np.ceil(np.logspace(0, np.log10(tmax), nt, base=10))
        self.nts = self.nts * 2
        self.models = []
        self.tmax = np.sum(model.dts)

        for nt in self.nts:
            m = deepcopy(model)
            m.nt = nt
            m.dt = self.tmax/nt
            print(m.dt)
            m._compute()
            self.models.append(m)
        
        self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
    
    def plot(self):
        nts = self.nts
        errors = self.errors
        plt.yscale("log")
        plt.xscale("log")
        p = plt.plot(self.tmax/nts, errors)
        plt.scatter(self.tmax/nts, errors)

        plt.xlabel(r'''step-size $\Delta T$''')        
        plt.ylabel(r'''error $\epsilon$''')
        plt.savefig("dwerror.png")
        return p

# %%
class DoubleWell:
    def __init__(self, nx = 5, ny = 1, xlims=(-1.5,1.5), ylims=(-1.5,1.5), dt=1, nt=4, beta=1):
        xs = np.linspace(*xlims, nx)
        ys = np.linspace(*ylims, ny)
        self.xs, self.ys = np.meshgrid(xs, ys, sparse=True)
        self.beta = beta

        self.nt = nt
        self.dt = dt
        self.nx = nx * ny
        self._compute()

    def _compute(self):
        self.dts = np.repeat(self.dt, self.nt)
        self.u = self.potential()
        self.sqra = sqra.Sqra(self.u, beta=self.beta)
        # use the commented version for dense computation
        #self.Qs = [self.sqra.Q.toarray()]*len(self.dt)
        self.Qs = [self.sqra.Q]*len(self.dts)
    
    def potential(self):
        return (self.xs**2-1)**2 + self.ys**2

    def name(self):
        return "dw"

# %%
class TripleWell(DoubleWell):
    def __init__(self, xlims=(-2, 2), ylims=(-1, 2), **kwargs):
        super().__init__(xlims=xlims, ylims=ylims, **kwargs)

    def potential(self):
        x = self.xs
        y = self.ys
        V = (3/4 * np.exp(-x**2 - (y-1/3)**2)
            - 3/4 * np.exp(-x**2 - (y-5/3)**2)
            - 5/4 * np.exp(-(x-1)**2 - y**2)
            - 5/4 * np.exp(-(x+1)**2 - y**2)
            + 1/20 * x**4 + 1/20 * (y-1/3)**4)
        return V

    def name(self):
        return "tw"

# %%
class TripleWellBeta(TripleWell):
    def __init__(self, beta1, beta2, **kwargs):
        self.beta1 = beta1
        self.beta2 = beta2
        
        super().__init__(**kwargs)

        assert self.nt % 2 == 0
        assert self.nt > 1

        
    def _compute(self):
        self.dts = np.repeat(self.dt, self.nt)
        self.u = self.potential()
        self.sqras = [sqra.Sqra(self.u, beta=self.beta1),
                      sqra.Sqra(self.u, beta=self.beta2)]
        # use the commented version for dense computation
        #self.Qs = [self.sqra.Q.toarray()]*len(self.dt)

        h = self.xs[0,1]-self.xs[0,0]
        #assert np.isclose(self.h, self.ys[1,0]-self.ys[0,0])
        nhalf = np.int(np.floor(self.nt/2))
        phi1 = 1 / (h*h*self.beta1)
        phi2 = 1 / (h*h*self.beta2)
        self.Qs = [phi1 * self.sqras[0].Q] * nhalf
        self.Qs = np.append(self.Qs, [phi2 * self.sqras[1].Q] * nhalf)

    def name(self):
        return "twb"

# %%
m=TripleWellBeta(1,10, nx=9, ny=7, nt=6, dt=.2)
mpaper=TripleWellBeta(1,10, nx=9, ny=7, nt=6, dt=1/3) # paper
mbig = TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=1/3)

m = mpaper
pb = PaperPlotsSparse(m)

# %%
# %time x = pb.koopman_sync()
plt.imshow(x)
# Out:
# CPU times: user 644 ms, sys: 7.86 ms, total: 652 ms
# Wall time: 708 ms

# %%
# %time x = pb.koopman_q()
plt.imshow(x.toarray())
# Out:
# CPU times: user 179 ms, sys: 4.92 ms, total: 184 ms
# Wall time: 290 ms

# %%
# %time x=pb.ajcs.koopman_system_iterated()
plt.imshow(x)
# Out:
# CPU times: user 464 ms, sys: 8.84 ms, total: 473 ms
# Wall time: 515 ms

# %%
# %time x = pb.ajcs.koopman_system()
plt.imshow(x)
# Out:
# CPU times: user 13 ms, sys: 2.12 ms, total: 15.1 ms
# Wall time: 17.6 ms

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

pb.plot_transkernel()
plt.clim(0,0.1)
tx, lb = [i*pb.nx - .5 for i in range(7)], ["" if i%3 > 0 else f"t={np.int(i/3)}" for i in range(7)]
plt.xticks(tx,lb)
plt.yticks(tx,lb)
plt.grid(alpha=.5)
plt.savefig("ex2k.pdf", bbox_inches="tight")
plt.show()

# %%
ntot = np.prod(pb.kernelmatrix().shape)
nnz  = np.sum(pb.kernelmatrix() > 0)
ntot, nnz, nnz/ntot
# Out:
# (142884, 4620, 0.03233392122281011)

# %%
plt.spy(pb.kernelmatrix())
plt.xlabel("X x T")
plt.ylabel("X x T")
plt.xticks([])
plt.yticks([])
plt.savefig("ex2s.pdf", bbox_inches="tight")

# %%
ae = ApproximationError(m, tmax=100, nt=10)
# Out:
# 0.9999999999999999
# 0.49999999999999994
# 0.3333333333333333
# 0.19999999999999998
# 0.12499999999999999
# 0.07692307692307691
# 0.04545454545454545
# 0.027777777777777776
# 0.016666666666666666
# 0.009999999999999998

# %%
size=3
plt.figure(figsize=(3*1.618,3))
plt.rc('text', usetex=True)
ae.plot()
plt.grid(which="major",alpha=.3)
plt.savefig("tw_error.pdf", bbox_inches="tight")

# %% [markdown]
# p0 = np.zeros((m.nx, m.nt))
# p0[:,0] = 1 / m.nx
# pb.plot_sync(0, p0)

# %% [markdown]
# d = DoubleWell(nx=20)
# d = DoubleWell(nx=5, xlims=(-2,2),dt=1, nt=5)
# t = TripleWell(nx=10, ny=8, nt=10)
#
# model = t

# %%
class TwoGraph:
    def __init__(self, nt = 2, dt=1):
        q1 = 1
        q0 = 1e-6
        self.Q1 = np.array([[-q1,q1],[q0,-q0]])
        self.Q2 = np.array([[-q0, q0],[q1,-q1]])
        self.nx = 2
        self.nt = nt
        self.Qs = np.zeros((self.nx,self.nx,self.nt))
        
        for i in range(nt):
            self.Qs[:,:,i] = self.Q1 if i/nt < .5 else self.Q2

        self.Qs = [self.Q1 if i/nt < .5 else self.Q2 for i in range(nt)]

        self.dts = [dt]*nt
        #self.dts[0] = 1e-5
        #self.dts[-1] = 1e-5

    def name(self):
        return "twograph"

# %%
class SingleQ:
    def __init__(self, Q, nt = 2, dt=1):
        self.Qs = [Q for i in range(nt)]
        self.dts = [dt]*nt
        self.nx = np.size(Q,0)
        self.nt = nt
        self.x0 = np.zeros((nt, self.nx))
        self.x0[0,0] = 1
    
    def name(self):
        return "simpleq"

Q =  np.array([[-2,1,1],[1,-2,1],[1, 0, -1]])
qm = SingleQ(Q, nt=10, dt=.2)
pqm = PaperPlots(qm)

# %%
pqm.plot_all(save=True)

# %%
p = plt.imshow(qm.x0.T)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/x0.pdf")

# %%
jx0 = pqm.ajc.jump(qm.x0.T)
p = plt.imshow(jx0)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/jx0.pdf")

# %%
jx1 = pqm.ajc.jump(jx0)
p = plt.imshow(jx1)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/jx1.pdf")

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

g = TwoGraph(nt=8, dt=1)
PaperPlots(g).plot_all(save=True)

# %%
pg = PaperPlots(g)
p = plt.imshow(pg.kernelmatrix(), interpolation="nearest")

cb = plt.colorbar()
plt.xticks([], labels=None)
tx, lb = [i*2 - .5 for i in range(9)], ["" if i%4 > 0 else f"t={i}" for i in range(9)]
plt.xticks(tx,lb)
plt.yticks(np.array(tx)-0.05, lb)
plt.grid(alpha=.4)
plt.xlabel("X x T")
plt.ylabel("X x T")
plt.savefig("ex1k.pdf", bbox_inches="tight")

# %%
p = pg.plot_jumpactivity()
plt.clim(0,1)
plt.savefig("ex1a.pdf")

# %%
def evolutionplots(self):
        x0 = 0
        p0 = np.zeros((self.nx,self.nt))
        p0[x0,0] = 1

        ax1 = plt.subplot(211)

        

        p = plt.imshow(self.jumpactivity(p0))
        plt.clim(0,1)
        #cb = plt.colorbar()
        #cb.set_label("jump activity")

        plt.ylabel("X")

        #plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        plt.yticks([0,1],["A","B"])
        plt.xticks([])

        ps = self.sync(p0)
        ax2 = plt.subplot(212)

        p = plt.imshow(ps)
        plt.clim(0,1)
        #cb = plt.colorbar()
        #cb.set_label("probability (synchronized, one state)")

        plt.ylabel("X")
        plt.xlabel("T")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        plt.yticks([0,1],["A","B"])
        #plt.subplots_adjust(hspace=0.8)

        plt.colorbar(ax = [ax1, ax2], location="top", shrink=0.94, ticks=[0,1], anchor=(0.5,0.6))

evolutionplots(pg)
plt.savefig("ex1ev.pdf", bbox_inches="tight")

# %%
p = pg.plot_sync()
plt.clim(0,1)
plt.colorbar(orientation="horizontal")
plt.savefig("ex1s.pdf")

# %%
ae.nts
# Out:
# array([  2.,   4.,   6.,  10.,  16.,  26.,  44.,  72., 120., 200.])

# %%
b2=TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=.2)
ae2 = ApproximationError(b2, tmax=50, nt=5)
# Out:
# 0.6
# 0.19999999999999998
# 0.075
# 0.031578947368421054
# 0.012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-236-0fa539d11f2a> in <module>
#       1 b2=TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=.2)
# ----> 2 ae2 = ApproximationError(b2, tmax=50, nt=5)
#
# <ipython-input-212-5e2060bb46a9> in __init__(self, model, nt, tmax)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-212-5e2060bb46a9> in <listcomp>(.0)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-211-fb79ac64cb3c> in koopman_error(self)
#      30         #ks = self.ajcs.koopman_system()
#      31         ks = self.koopman_sync()
# ---> 32         kq = self.koopman_q()
#      33         return np.linalg.norm(ks-kq, 2)
#
# <ipython-input-211-fb79ac64cb3c> in koopman_q(self)
#      24         k = sps.identity(self.nx)
#      25         for (i,t) in enumerate(self.dt):
# ---> 26             k = k @ spl.expm(t * self.Qs[i])
#      27         return k
#      28
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/linalg/matfuncs.py in expm(A)
#     590             [  0.        ,   0.        ,  20.08553692]])
#     591     """
# --> 592     return _expm(A, use_exact_onenorm='auto')
#     593
#     594
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/linalg/matfuncs.py in _expm(A, use_exact_onenorm)
#     679         # X = r_13(A)^(2^s) by repeated squaring.
#     680         for i in range(s):
# --> 681             X = X.dot(X)
#     682     return X
#     683
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/base.py in dot(self, other)
#     357
#     358         """
# --> 359         return self * other
#     360
#     361     def power(self, n, dtype=None):
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     478             if self.shape[1] != other.shape[0]:
#     479                 raise ValueError('dimension mismatch')
# --> 480             return self._mul_sparse_matrix(other)
#     481
#     482         # If it's a list or whatever, treat it like a matrix
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/compressed.py in _mul_sparse_matrix(self, other)
#     518
#     519         fn = getattr(_sparsetools, self.format + '_matmat')
# --> 520         fn(M, N, np.asarray(self.indptr, dtype=idx_dtype),
#     521            np.asarray(self.indices, dtype=idx_dtype),
#     522            self.data,
#
# KeyboardInterrupt:

# %%
ae.plot()
ae2.plot()

# %%
x=np.vstack(np.array(expm(t*m.Qs[1]).todense())[:,0].reshape(-1) for t in np.arange(0,1,0.01))

# %%
plt.plot(x)
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
x
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.40676381, 0.20654371, 0.04514039, ..., 0.0448179 , 0.19749515,
#         0.41873941],
#        [0.20819027, 0.18322067, 0.07483729, ..., 0.07425613, 0.17696359,
#         0.22030365],
#        ...,
#        [0.0370442 , 0.06175129, 0.0590488 , ..., 0.05415973, 0.05679795,
#         0.03973503],
#        [0.03081825, 0.05339125, 0.0539496 , ..., 0.04828746, 0.04776329,
#         0.03227414],
#        [0.02638411, 0.04707143, 0.04959579, ..., 0.04328902, 0.04084043,
#         0.02683573]])
